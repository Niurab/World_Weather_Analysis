# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 786

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 2 of Set 1 | nemuro
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | ribeira brava
# Processing Record 9 of Set 1 | caravelas
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | kijang
# Processing Record 12 of Set 1 | tias
# Processing Record 13 of Set 1 | sovetskaya gavan
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | gornyy
# Processing Record 16 of Set 1 | santa fe do sul
# Processing Record 17 of Set 1 | harper
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | nanortalik
# Processing Record 22 of Set 1 | vogar
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | itaituba
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | sur
# Processing Record 33 of Set 1 | dakar
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | rovaniemi
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | marcona
# City not found. Skipping
# Processing Record 38 of Set 1 | igrim
# Processing Record 39 of Set 1 | hun
# Processing Record 40 of Set 1 | yashan
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | hambantota
# Processing Record 44 of Set 1 | temaraia
# City not found. Skipping
# Processing Record 45 of Set 1 | hovd
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | warmbad
# Processing Record 48 of Set 1 | havre-saint-pierre
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | bissau
# Processing Record 3 of Set 2 | cayenne
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | tawnat
# City not found. Skipping
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | zittau
# Processing Record 11 of Set 2 | itoman
# Processing Record 12 of Set 2 | mana
# Processing Record 13 of Set 2 | poum
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | kalabo
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | turinsk
# Processing Record 22 of Set 2 | zonguldak
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | manggar
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | isangel
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | tateyama
# Processing Record 30 of Set 2 | wahiawa
# Processing Record 31 of Set 2 | biltine
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | yeppoon
# Processing Record 36 of Set 2 | kloulklubed
# Processing Record 37 of Set 2 | huntsville
# Processing Record 38 of Set 2 | surskoye
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | hammerfest
# Processing Record 41 of Set 2 | farafangana
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | muyezerskiy
# Processing Record 45 of Set 2 | chililabombwe
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 47 of Set 2 | prainha
# Processing Record 48 of Set 2 | meulaboh
# Processing Record 49 of Set 2 | muzhi
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | oga
# Processing Record 2 of Set 3 | bathsheba
# Processing Record 3 of Set 3 | gazojak
# Processing Record 4 of Set 3 | yaan
# Processing Record 5 of Set 3 | miri
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 7 of Set 3 | lolua
# City not found. Skipping
# Processing Record 8 of Set 3 | grindavik
# Processing Record 9 of Set 3 | toliary
# City not found. Skipping
# Processing Record 10 of Set 3 | luderitz
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | eskasem
# City not found. Skipping
# Processing Record 13 of Set 3 | karauzyak
# City not found. Skipping
# Processing Record 14 of Set 3 | evensk
# Processing Record 15 of Set 3 | chagda
# City not found. Skipping
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping
# Processing Record 17 of Set 3 | dzaoudzi
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | myaundzha
# Processing Record 20 of Set 3 | kyaukse
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | shaki
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | samarai
# Processing Record 25 of Set 3 | jacmel
# Processing Record 26 of Set 3 | angra
# City not found. Skipping
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | zabaykalsk
# Processing Record 30 of Set 3 | sozopol
# Processing Record 31 of Set 3 | xining
# Processing Record 32 of Set 3 | beyneu
# Processing Record 33 of Set 3 | katsuura
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | zima
# Processing Record 36 of Set 3 | sinkat
# City not found. Skipping
# Processing Record 37 of Set 3 | corinto
# Processing Record 38 of Set 3 | yakeshi
# Processing Record 39 of Set 3 | ketchikan
# Processing Record 40 of Set 3 | hue
# Processing Record 41 of Set 3 | pa daet
# Processing Record 42 of Set 3 | nyurba
# Processing Record 43 of Set 3 | codrington
# Processing Record 44 of Set 3 | salinas
# Processing Record 45 of Set 3 | banda aceh
# Processing Record 46 of Set 3 | tautira
# Processing Record 47 of Set 3 | gwembe
# Processing Record 48 of Set 3 | poplar bluff
# Processing Record 49 of Set 3 | kapaa
# Processing Record 50 of Set 3 | itoigawa
# Processing Record 1 of Set 4 | erzin
# Processing Record 2 of Set 4 | baykalsk
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | morant bay
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | altamira
# Processing Record 7 of Set 4 | syumsi
# Processing Record 8 of Set 4 | tokur
# Processing Record 9 of Set 4 | hermanus
# Processing Record 10 of Set 4 | westport
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | vaitupu
# City not found. Skipping
# Processing Record 13 of Set 4 | majene
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping
# Processing Record 16 of Set 4 | rio gallegos
# Processing Record 17 of Set 4 | barrhead
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | gushikawa
# Processing Record 21 of Set 4 | kyzyl-suu
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | cockburn town
# Processing Record 24 of Set 4 | nangomba
# Processing Record 25 of Set 4 | lamar
# Processing Record 26 of Set 4 | alofi
# Processing Record 27 of Set 4 | tumannyy
# City not found. Skipping
# Processing Record 28 of Set 4 | peniche
# Processing Record 29 of Set 4 | nordfjordeid
# Processing Record 30 of Set 4 | korhogo
# Processing Record 31 of Set 4 | kyra
# Processing Record 32 of Set 4 | shakiso
# Processing Record 33 of Set 4 | mutis
# Processing Record 34 of Set 4 | muros
# Processing Record 35 of Set 4 | makakilo city
# Processing Record 36 of Set 4 | bubaque
# Processing Record 37 of Set 4 | natal
# Processing Record 38 of Set 4 | kracheh
# City not found. Skipping
# Processing Record 39 of Set 4 | effingham
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | canavieiras
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | biak
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | antalaha
# Processing Record 46 of Set 4 | pangnirtung
# Processing Record 47 of Set 4 | astana
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | pailon
# Processing Record 50 of Set 4 | thomasville
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | nogales
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | srednekolymsk
# Processing Record 6 of Set 5 | port blair
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | la uribe
# City not found. Skipping
# Processing Record 9 of Set 5 | meyungs
# City not found. Skipping
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | ust-nera
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | balkanabat
# Processing Record 14 of Set 5 | atherton
# Processing Record 15 of Set 5 | dharchula
# Processing Record 16 of Set 5 | san cristobal
# Processing Record 17 of Set 5 | charlestown
# Processing Record 18 of Set 5 | mortka
# Processing Record 19 of Set 5 | kahului
# Processing Record 20 of Set 5 | mehamn
# Processing Record 21 of Set 5 | ossora
# Processing Record 22 of Set 5 | oyama
# Processing Record 23 of Set 5 | salalah
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | manwath
# City not found. Skipping
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | avera
# Processing Record 28 of Set 5 | diapaga
# Processing Record 29 of Set 5 | walvis bay
# Processing Record 30 of Set 5 | auki
# Processing Record 31 of Set 5 | kununurra
# Processing Record 32 of Set 5 | honningsvag
# Processing Record 33 of Set 5 | amapa
# Processing Record 34 of Set 5 | essau
# Processing Record 35 of Set 5 | nanakuli
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | hithadhoo
# Processing Record 38 of Set 5 | saint-joseph
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | horconcitos
# Processing Record 42 of Set 5 | yialos
# City not found. Skipping
# Processing Record 43 of Set 5 | umm lajj
# Processing Record 44 of Set 5 | lyngdal
# Processing Record 45 of Set 5 | chaihe
# Processing Record 46 of Set 5 | bima
# Processing Record 47 of Set 5 | misratah
# Processing Record 48 of Set 5 | chokurdakh
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | abu jubayhah
# City not found. Skipping
# Processing Record 3 of Set 6 | namatanai
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | luau
# Processing Record 6 of Set 6 | pevek
# Processing Record 7 of Set 6 | hofn
# Processing Record 8 of Set 6 | foam lake
# Processing Record 9 of Set 6 | batemans bay
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | beringovskiy
# Processing Record 12 of Set 6 | kang
# Processing Record 13 of Set 6 | kushiro
# Processing Record 14 of Set 6 | fairbanks
# Processing Record 15 of Set 6 | talcahuano
# Processing Record 16 of Set 6 | wanaka
# Processing Record 17 of Set 6 | yanan
# City not found. Skipping
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | acapulco
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | sarangani
# Processing Record 22 of Set 6 | jalu
# Processing Record 23 of Set 6 | paragould
# Processing Record 24 of Set 6 | camana
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | kurunegala
# Processing Record 27 of Set 6 | taltal
# Processing Record 28 of Set 6 | bairiki
# Processing Record 29 of Set 6 | ende
# Processing Record 30 of Set 6 | dzialdowo
# Processing Record 31 of Set 6 | mokobeng
# Processing Record 32 of Set 6 | kautokeino
# Processing Record 33 of Set 6 | kasongo-lunda
# Processing Record 34 of Set 6 | zuwarah
# Processing Record 35 of Set 6 | tiksi
# Processing Record 36 of Set 6 | boddam
# Processing Record 37 of Set 6 | saldanha
# Processing Record 38 of Set 6 | saint anthony
# Processing Record 39 of Set 6 | pacific grove
# Processing Record 40 of Set 6 | sabang
# Processing Record 41 of Set 6 | corning
# Processing Record 42 of Set 6 | nyazepetrovsk
# Processing Record 43 of Set 6 | ibatiba
# Processing Record 44 of Set 6 | chapada dos guimaraes
# Processing Record 45 of Set 6 | tagusao
# Processing Record 46 of Set 6 | rio claro
# Processing Record 47 of Set 6 | tabulbah
# City not found. Skipping
# Processing Record 48 of Set 6 | cobija
# Processing Record 49 of Set 6 | mangan
# Processing Record 50 of Set 6 | saint-augustin
# Processing Record 1 of Set 7 | negotino
# Processing Record 2 of Set 7 | terrace
# Processing Record 3 of Set 7 | bilma
# Processing Record 4 of Set 7 | ruatoria
# City not found. Skipping
# Processing Record 5 of Set 7 | mount gambier
# Processing Record 6 of Set 7 | talnakh
# Processing Record 7 of Set 7 | darhan
# Processing Record 8 of Set 7 | carutapera
# Processing Record 9 of Set 7 | homer
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | utiroa
# City not found. Skipping
# Processing Record 12 of Set 7 | sakakah
# Processing Record 13 of Set 7 | tatawin
# Processing Record 14 of Set 7 | wamba
# Processing Record 15 of Set 7 | san carlos
# Processing Record 16 of Set 7 | neyshabur
# Processing Record 17 of Set 7 | acari
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | ixtapa
# Processing Record 20 of Set 7 | catamarca
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | the valley
# Processing Record 23 of Set 7 | gondar
# Processing Record 24 of Set 7 | inhambane
# Processing Record 25 of Set 7 | bambanglipuro
# Processing Record 26 of Set 7 | oriximina
# Processing Record 27 of Set 7 | yushan
# Processing Record 28 of Set 7 | nizhnevartovsk
# Processing Record 29 of Set 7 | pontianak
# Processing Record 30 of Set 7 | asau
# Processing Record 31 of Set 7 | bull savanna
# Processing Record 32 of Set 7 | izmaylovo
# Processing Record 33 of Set 7 | thompson
# Processing Record 34 of Set 7 | uinskoye
# Processing Record 35 of Set 7 | sioux lookout
# Processing Record 36 of Set 7 | jizan
# Processing Record 37 of Set 7 | mar del plata
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | camacupa
# Processing Record 40 of Set 7 | tabiauea
# City not found. Skipping
# Processing Record 41 of Set 7 | kalininsk
# Processing Record 42 of Set 7 | ostuacan
# Processing Record 43 of Set 7 | kuche
# City not found. Skipping
# Processing Record 44 of Set 7 | marzuq
# Processing Record 45 of Set 7 | necochea
# Processing Record 46 of Set 7 | bardiyah
# Processing Record 47 of Set 7 | yen bai
# Processing Record 48 of Set 7 | nizhnyaya tavda
# Processing Record 49 of Set 7 | sangar
# Processing Record 50 of Set 7 | ariquemes
# Processing Record 1 of Set 8 | nisia floresta
# Processing Record 2 of Set 8 | longyearbyen
# Processing Record 3 of Set 8 | turukhansk
# Processing Record 4 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 8 | plettenberg bay
# Processing Record 6 of Set 8 | okha
# Processing Record 7 of Set 8 | teya
# Processing Record 8 of Set 8 | hamilton
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | faro
# Processing Record 11 of Set 8 | yulara
# Processing Record 12 of Set 8 | coahuayana
# Processing Record 13 of Set 8 | whitehorse
# Processing Record 14 of Set 8 | batagay-alyta
# Processing Record 15 of Set 8 | verkhovazhye
# Processing Record 16 of Set 8 | amasya
# Processing Record 17 of Set 8 | edgewater
# Processing Record 18 of Set 8 | mtimbira
# Processing Record 19 of Set 8 | bay roberts
# Processing Record 20 of Set 8 | la peca
# Processing Record 21 of Set 8 | swinford
# Processing Record 22 of Set 8 | gatesville
# Processing Record 23 of Set 8 | san-pedro
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | antofagasta
# Processing Record 26 of Set 8 | udachnyy
# Processing Record 27 of Set 8 | ozerki
# Processing Record 28 of Set 8 | atambua
# Processing Record 29 of Set 8 | menongue
# Processing Record 30 of Set 8 | rungata
# City not found. Skipping
# Processing Record 31 of Set 8 | khatanga
# Processing Record 32 of Set 8 | san juan
# Processing Record 33 of Set 8 | rorvik
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | traralgon
# Processing Record 36 of Set 8 | visby
# Processing Record 37 of Set 8 | barawe
# City not found. Skipping
# Processing Record 38 of Set 8 | saint-paul
# Processing Record 39 of Set 8 | iranshahr
# Processing Record 40 of Set 8 | agadir
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | goderich
# Processing Record 43 of Set 8 | verkhoyansk
# Processing Record 44 of Set 8 | saskylakh
# Processing Record 45 of Set 8 | keti bandar
# Processing Record 46 of Set 8 | reggio di calabria
# Processing Record 47 of Set 8 | podyuga
# Processing Record 48 of Set 8 | karakendzha
# City not found. Skipping
# Processing Record 49 of Set 8 | ostrovnoy
# Processing Record 50 of Set 8 | lamu
# Processing Record 1 of Set 9 | dingle
# Processing Record 2 of Set 9 | seymchan
# Processing Record 3 of Set 9 | rio grande
# Processing Record 4 of Set 9 | vyshneve
# Processing Record 5 of Set 9 | chifeng
# Processing Record 6 of Set 9 | nome
# Processing Record 7 of Set 9 | yamada
# Processing Record 8 of Set 9 | pedernales
# Processing Record 9 of Set 9 | doka
# Processing Record 10 of Set 9 | sarai alamgir
# Processing Record 11 of Set 9 | chara
# Processing Record 12 of Set 9 | tezu
# Processing Record 13 of Set 9 | khani
# Processing Record 14 of Set 9 | eyl
# Processing Record 15 of Set 9 | petatlan
# Processing Record 16 of Set 9 | porto novo
# Processing Record 17 of Set 9 | tilichiki
# Processing Record 18 of Set 9 | mildura
# Processing Record 19 of Set 9 | zhigansk
# Processing Record 20 of Set 9 | virginia beach
# Processing Record 21 of Set 9 | armacao dos buzios
# City not found. Skipping
# Processing Record 22 of Set 9 | buta
# Processing Record 23 of Set 9 | bahir dar
# Processing Record 24 of Set 9 | tutoia
# Processing Record 25 of Set 9 | jabiru
# City not found. Skipping
# Processing Record 26 of Set 9 | lakatoro
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | malanje
# Processing Record 29 of Set 9 | riyadh
# Processing Record 30 of Set 9 | grand gaube
# Processing Record 31 of Set 9 | tarquinia
# Processing Record 32 of Set 9 | flin flon
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | coruripe
# Processing Record 36 of Set 9 | mnogovershinnyy
# Processing Record 37 of Set 9 | mikhaylovskoye
# Processing Record 38 of Set 9 | nouadhibou
# Processing Record 39 of Set 9 | port-gentil
# Processing Record 40 of Set 9 | imbituba
# Processing Record 41 of Set 9 | kudat
# Processing Record 42 of Set 9 | yarmouth
# Processing Record 43 of Set 9 | la palma
# Processing Record 44 of Set 9 | berlevag
# Processing Record 45 of Set 9 | ola
# Processing Record 46 of Set 9 | caldwell
# Processing Record 47 of Set 9 | louisbourg
# City not found. Skipping
# Processing Record 48 of Set 9 | port augusta
# Processing Record 49 of Set 9 | margate
# Processing Record 50 of Set 9 | arlit
# Processing Record 1 of Set 10 | la paz
# Processing Record 2 of Set 10 | mahibadhoo
# Processing Record 3 of Set 10 | valparaiso
# Processing Record 4 of Set 10 | rocky mount
# Processing Record 5 of Set 10 | kaeo
# Processing Record 6 of Set 10 | kargopol
# Processing Record 7 of Set 10 | singaperumalkoil
# City not found. Skipping
# Processing Record 8 of Set 10 | sabha
# Processing Record 9 of Set 10 | flinders
# Processing Record 10 of Set 10 | marienburg
# Processing Record 11 of Set 10 | japura
# Processing Record 12 of Set 10 | boundiali
# Processing Record 13 of Set 10 | bolungarvik
# City not found. Skipping
# Processing Record 14 of Set 10 | ust-ishim
# Processing Record 15 of Set 10 | nantucket
# Processing Record 16 of Set 10 | varna
# Processing Record 17 of Set 10 | nizhnekamsk
# Processing Record 18 of Set 10 | boden
# Processing Record 19 of Set 10 | mys shmidta
# City not found. Skipping
# Processing Record 20 of Set 10 | zarubino
# Processing Record 21 of Set 10 | manado
# Processing Record 22 of Set 10 | asayita
# City not found. Skipping
# Processing Record 23 of Set 10 | smithers
# Processing Record 24 of Set 10 | sayansk
# Processing Record 25 of Set 10 | te anau
# Processing Record 26 of Set 10 | barcelos
# Processing Record 27 of Set 10 | silifke
# Processing Record 28 of Set 10 | thomaston
# Processing Record 29 of Set 10 | kamaishi
# Processing Record 30 of Set 10 | soure
# Processing Record 31 of Set 10 | yanchukan
# City not found. Skipping
# Processing Record 32 of Set 10 | maloshuyka
# City not found. Skipping
# Processing Record 33 of Set 10 | kruisfontein
# Processing Record 34 of Set 10 | deputatskiy
# Processing Record 35 of Set 10 | buchanan
# Processing Record 36 of Set 10 | tongzi
# Processing Record 37 of Set 10 | breves
# Processing Record 38 of Set 10 | abu samrah
# Processing Record 39 of Set 10 | kyabe
# Processing Record 40 of Set 10 | beira
# Processing Record 41 of Set 10 | kendari
# Processing Record 42 of Set 10 | komatipoort
# Processing Record 43 of Set 10 | otsuki
# Processing Record 44 of Set 10 | armidale
# Processing Record 45 of Set 10 | satitoa
# City not found. Skipping
# Processing Record 46 of Set 10 | shar
# Processing Record 47 of Set 10 | maceio
# Processing Record 48 of Set 10 | springdale
# Processing Record 49 of Set 10 | tual
# Processing Record 50 of Set 10 | souillac
# Processing Record 1 of Set 11 | victoria point
# Processing Record 2 of Set 11 | norman wells
# Processing Record 3 of Set 11 | nara
# Processing Record 4 of Set 11 | paamiut
# Processing Record 5 of Set 11 | cairns
# Processing Record 6 of Set 11 | tera
# Processing Record 7 of Set 11 | gizo
# Processing Record 8 of Set 11 | north bend
# Processing Record 9 of Set 11 | agirish
# Processing Record 10 of Set 11 | aqtobe
# Processing Record 11 of Set 11 | trairi
# Processing Record 12 of Set 11 | kondopoga
# Processing Record 13 of Set 11 | dwarka
# Processing Record 14 of Set 11 | syzran
# Processing Record 15 of Set 11 | svetlaya
# Processing Record 16 of Set 11 | san quintin
# Processing Record 17 of Set 11 | luena
# Processing Record 18 of Set 11 | bayabas
# Processing Record 19 of Set 11 | lenger
# Processing Record 20 of Set 11 | chik
# Processing Record 21 of Set 11 | saint-francois
# Processing Record 22 of Set 11 | zeya
# Processing Record 23 of Set 11 | huescar
# Processing Record 24 of Set 11 | weihai
# Processing Record 25 of Set 11 | dibrugarh
# Processing Record 26 of Set 11 | godo
# Processing Record 27 of Set 11 | asfi
# Processing Record 28 of Set 11 | bosaso
# Processing Record 29 of Set 11 | kisangani
# Processing Record 30 of Set 11 | hoi an
# Processing Record 31 of Set 11 | ponta delgada
# Processing Record 32 of Set 11 | kieta
# Processing Record 33 of Set 11 | abashiri
# Processing Record 34 of Set 11 | atasu
# Processing Record 35 of Set 11 | rosita
# Processing Record 36 of Set 11 | shiraoi
# Processing Record 37 of Set 11 | borama
# City not found. Skipping
# Processing Record 38 of Set 11 | severobaykalsk
# Processing Record 39 of Set 11 | novosil
# Processing Record 40 of Set 11 | aflu
# City not found. Skipping
# Processing Record 41 of Set 11 | maun
# Processing Record 42 of Set 11 | buala
# Processing Record 43 of Set 11 | entre rios
# Processing Record 44 of Set 11 | saint-louis
# Processing Record 45 of Set 11 | tejupilco
# City not found. Skipping
# Processing Record 46 of Set 11 | axim
# Processing Record 47 of Set 11 | sinnamary
# Processing Record 48 of Set 11 | moissac
# Processing Record 49 of Set 11 | iralaya
# Processing Record 50 of Set 11 | morondava
# Processing Record 1 of Set 12 | vostok
# Processing Record 2 of Set 12 | tommot
# Processing Record 3 of Set 12 | winnemucca
# Processing Record 4 of Set 12 | veraval
# Processing Record 5 of Set 12 | rawson
# Processing Record 6 of Set 12 | naze
# Processing Record 7 of Set 12 | yatou
# Processing Record 8 of Set 12 | cheuskiny
# City not found. Skipping
# Processing Record 9 of Set 12 | waiouru
# Processing Record 10 of Set 12 | praya
# Processing Record 11 of Set 12 | fort saint john
# City not found. Skipping
# Processing Record 12 of Set 12 | semirom
# Processing Record 13 of Set 12 | takoradi
# Processing Record 14 of Set 12 | conakry
# Processing Record 15 of Set 12 | tura
# Processing Record 16 of Set 12 | ndende
# Processing Record 17 of Set 12 | nioki
# Processing Record 18 of Set 12 | male
# Processing Record 19 of Set 12 | pochutla
# Processing Record 20 of Set 12 | lompoc
# Processing Record 21 of Set 12 | paso de patria
# Processing Record 22 of Set 12 | mahadday weyne
# City not found. Skipping
# Processing Record 23 of Set 12 | cabinda
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | dunedin
# Processing Record 26 of Set 12 | guaruja
# Processing Record 27 of Set 12 | katherine
# Processing Record 28 of Set 12 | saint-georges
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | sorland
# Processing Record 31 of Set 12 | aksu
# Processing Record 32 of Set 12 | tuy hoa
# Processing Record 33 of Set 12 | ruangwa
# Processing Record 34 of Set 12 | myskhako
# Processing Record 35 of Set 12 | iqaluit
# Processing Record 36 of Set 12 | mazarron
# Processing Record 37 of Set 12 | nuevo casas grandes
# Processing Record 38 of Set 12 | rena
# Processing Record 39 of Set 12 | almenara
# Processing Record 40 of Set 12 | aklavik
# Processing Record 41 of Set 12 | deep river
# Processing Record 42 of Set 12 | pisco
# Processing Record 43 of Set 12 | ilinogorsk
# City not found. Skipping
# Processing Record 44 of Set 12 | krasnoselkup
# Processing Record 45 of Set 12 | egvekinot
# Processing Record 46 of Set 12 | ayorou
# Processing Record 47 of Set 12 | qianan
# Processing Record 48 of Set 12 | zvishavane
# Processing Record 49 of Set 12 | port keats
# Processing Record 50 of Set 12 | bilibino
# Processing Record 1 of Set 13 | lethem
# Processing Record 2 of Set 13 | ust-kamchatsk
# City not found. Skipping
# Processing Record 3 of Set 13 | banepa
# Processing Record 4 of Set 13 | beatrice
# Processing Record 5 of Set 13 | yuci
# Processing Record 6 of Set 13 | alice springs
# Processing Record 7 of Set 13 | olafsvik
# Processing Record 8 of Set 13 | cabedelo
# Processing Record 9 of Set 13 | baoqing
# Processing Record 10 of Set 13 | prado
# Processing Record 11 of Set 13 | shu
# Processing Record 12 of Set 13 | pringsewu
# Processing Record 13 of Set 13 | san andres
# Processing Record 14 of Set 13 | whitianga
# Processing Record 15 of Set 13 | wajir
# Processing Record 16 of Set 13 | zhanatas
# City not found. Skipping
# Processing Record 17 of Set 13 | corn island
# Processing Record 18 of Set 13 | grande-riviere
# City not found. Skipping
# Processing Record 19 of Set 13 | comodoro rivadavia
# Processing Record 20 of Set 13 | nagyvenyim
# Processing Record 21 of Set 13 | brainerd
# Processing Record 22 of Set 13 | eureka
# Processing Record 23 of Set 13 | san rafael
# Processing Record 24 of Set 13 | cap malheureux
# Processing Record 25 of Set 13 | houma
# Processing Record 26 of Set 13 | mendoza
# Processing Record 27 of Set 13 | herat
# Processing Record 28 of Set 13 | veranopolis
# Processing Record 29 of Set 13 | ancud
# Processing Record 30 of Set 13 | priladozhskiy
# Processing Record 31 of Set 13 | punta de bombon
# Processing Record 32 of Set 13 | tonder
# Processing Record 33 of Set 13 | hualmay
# Processing Record 34 of Set 13 | torbay
# Processing Record 35 of Set 13 | sao francisco
# Processing Record 36 of Set 13 | channel-port aux basques
# Processing Record 37 of Set 13 | partizanskoye
# Processing Record 38 of Set 13 | umzimvubu
# City not found. Skipping
# Processing Record 39 of Set 13 | collie
# Processing Record 40 of Set 13 | pipar
# Processing Record 41 of Set 13 | ojinaga
# Processing Record 42 of Set 13 | elbistan
# Processing Record 43 of Set 13 | khotkovo
# Processing Record 44 of Set 13 | richards bay
# Processing Record 45 of Set 13 | puerto leguizamo
# Processing Record 46 of Set 13 | sao felix do xingu
# Processing Record 47 of Set 13 | belmonte
# Processing Record 48 of Set 13 | inta
# Processing Record 49 of Set 13 | vilhena
# Processing Record 50 of Set 13 | guicheng
# City not found. Skipping
# Processing Record 1 of Set 14 | marystown
# Processing Record 2 of Set 14 | taoudenni
# Processing Record 3 of Set 14 | shitkino
# Processing Record 4 of Set 14 | wonthaggi
# Processing Record 5 of Set 14 | carndonagh
# Processing Record 6 of Set 14 | baruun-urt
# Processing Record 7 of Set 14 | culfa
# Processing Record 8 of Set 14 | porbandar
# Processing Record 9 of Set 14 | zyryanka
# Processing Record 10 of Set 14 | beniganj
# Processing Record 11 of Set 14 | nelson bay
# Processing Record 12 of Set 14 | paita
# Processing Record 13 of Set 14 | trujillo
# Processing Record 14 of Set 14 | akyab
# Processing Record 15 of Set 14 | manavalakurichi
# Processing Record 16 of Set 14 | sao joao da barra
# Processing Record 17 of Set 14 | choix
# Processing Record 18 of Set 14 | mayo
# Processing Record 19 of Set 14 | waingapu
# Processing Record 20 of Set 14 | nioro
# Processing Record 21 of Set 14 | ulladulla
# Processing Record 22 of Set 14 | nizhniy chir
# Processing Record 23 of Set 14 | binga
# Processing Record 24 of Set 14 | orocue
# Processing Record 25 of Set 14 | alugan
# Processing Record 26 of Set 14 | nauta
# Processing Record 27 of Set 14 | tsihombe
# City not found. Skipping
# Processing Record 28 of Set 14 | mastic beach
# Processing Record 29 of Set 14 | huarmey
# Processing Record 30 of Set 14 | zaanstad
# Processing Record 31 of Set 14 | nicoya
# Processing Record 32 of Set 14 | kavaratti
# Processing Record 33 of Set 14 | koslan
# Processing Record 34 of Set 14 | puteyets
# Processing Record 35 of Set 14 | berdigestyakh
# Processing Record 36 of Set 14 | nouakchott
# Processing Record 37 of Set 14 | haines junction
# Processing Record 38 of Set 14 | addi ugri
# City not found. Skipping
# Processing Record 39 of Set 14 | prabumulih
# Processing Record 40 of Set 14 | ambodifototra
# City not found. Skipping
# Processing Record 41 of Set 14 | hami
# Processing Record 42 of Set 14 | milford
# Processing Record 43 of Set 14 | karkaralinsk
# City not found. Skipping
# Processing Record 44 of Set 14 | medea
# Processing Record 45 of Set 14 | pandoh
# Processing Record 46 of Set 14 | tabas
# Processing Record 47 of Set 14 | khandbari
# Processing Record 48 of Set 14 | yumen
# Processing Record 49 of Set 14 | jamsa
# Processing Record 50 of Set 14 | genhe
# Processing Record 1 of Set 15 | georgiyevka
# Processing Record 2 of Set 15 | marrakesh
# Processing Record 3 of Set 15 | andevoranto
# City not found. Skipping
# Processing Record 4 of Set 15 | hengshui
# Processing Record 5 of Set 15 | lumphat
# Processing Record 6 of Set 15 | destin
# Processing Record 7 of Set 15 | pipri
# Processing Record 8 of Set 15 | cap-aux-meules
# Processing Record 9 of Set 15 | hazorasp
# Processing Record 10 of Set 15 | portland
# Processing Record 11 of Set 15 | abay
# Processing Record 12 of Set 15 | kitami
# Processing Record 13 of Set 15 | qasigiannguit
# Processing Record 14 of Set 15 | scottsbluff
# Processing Record 15 of Set 15 | pleasanton
# Processing Record 16 of Set 15 | sambava
# Processing Record 17 of Set 15 | dubbo
# Processing Record 18 of Set 15 | san vicente
# Processing Record 19 of Set 15 | athabasca
# Processing Record 20 of Set 15 | belaya gora
# Processing Record 21 of Set 15 | almaznyy
# Processing Record 22 of Set 15 | sola
# Processing Record 23 of Set 15 | cantanhede
# Processing Record 24 of Set 15 | bonfim
# Processing Record 25 of Set 15 | frutal
# Processing Record 26 of Set 15 | fort nelson
# Processing Record 27 of Set 15 | kashiwazaki
# Processing Record 28 of Set 15 | vologda
# Processing Record 29 of Set 15 | shakawe
# Processing Record 30 of Set 15 | mizan teferi
# Processing Record 31 of Set 15 | chongwe
# Processing Record 32 of Set 15 | atlantic city
# Processing Record 33 of Set 15 | tapaua
# City not found. Skipping
# Processing Record 34 of Set 15 | chicama
# Processing Record 35 of Set 15 | nuuk
# Processing Record 36 of Set 15 | thunder bay
# Processing Record 37 of Set 15 | heihe
# Processing Record 38 of Set 15 | samusu
# City not found. Skipping
# Processing Record 39 of Set 15 | bartica
# Processing Record 40 of Set 15 | suluq
# Processing Record 41 of Set 15 | tubuala
# Processing Record 42 of Set 15 | trinidad
# Processing Record 43 of Set 15 | boyuibe
# Processing Record 44 of Set 15 | vrangel
# Processing Record 45 of Set 15 | byron bay
# Processing Record 46 of Set 15 | ust-tsilma
# Processing Record 47 of Set 15 | sao jose da coroa grande
# Processing Record 48 of Set 15 | littlehampton
# Processing Record 49 of Set 15 | khipro
# Processing Record 50 of Set 15 | dneprovskaya
# Processing Record 1 of Set 16 | waipawa
# Processing Record 2 of Set 16 | vargem grande
# Processing Record 3 of Set 16 | elko
# Processing Record 4 of Set 16 | ust-bolsheretsk
# City not found. Skipping
# Processing Record 5 of Set 16 | khandyga
# Processing Record 6 of Set 16 | opuwo
# Processing Record 7 of Set 16 | zavodouspenskoye
# Processing Record 8 of Set 16 | scottsburgh
# City not found. Skipping
# Processing Record 9 of Set 16 | guayaramerin
# Processing Record 10 of Set 16 | san lawrenz
# Processing Record 11 of Set 16 | atar
# Processing Record 12 of Set 16 | paradwip
# City not found. Skipping
# Processing Record 13 of Set 16 | kesennuma
# City not found. Skipping
# Processing Record 14 of Set 16 | aleksandrov gay
# Processing Record 15 of Set 16 | kaseda
# Processing Record 16 of Set 16 | kysyl-syr
# Processing Record 17 of Set 16 | nampula
# Processing Record 18 of Set 16 | sosnovoborsk
# Processing Record 19 of Set 16 | san jeronimo
# Processing Record 20 of Set 16 | bereznik
# Processing Record 21 of Set 16 | derazhnya
# Processing Record 22 of Set 16 | mecca
# Processing Record 23 of Set 16 | escanaba
# Processing Record 24 of Set 16 | bereda
# Processing Record 25 of Set 16 | buqayq
# City not found. Skipping
# Processing Record 26 of Set 16 | george
# Processing Record 27 of Set 16 | urucara
# Processing Record 28 of Set 16 | poya
# Processing Record 29 of Set 16 | conway
# Processing Record 30 of Set 16 | shingu
# Processing Record 31 of Set 16 | bulawayo
# Processing Record 32 of Set 16 | celestun
# Processing Record 33 of Set 16 | ngunguru
# Processing Record 34 of Set 16 | panguna
# Processing Record 35 of Set 16 | kantang
# Processing Record 36 of Set 16 | soloneshnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Length of API call
len(city_data)
# Out:
# 715

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0         Nemuro      JP  2021-11-07 06:38:25  43.3236  145.5750     46.83
# 1         Narsaq      GL  2021-11-07 06:38:45  60.9167  -46.0500     34.02
# 2    Port Alfred      ZA  2021-11-07 06:38:06 -33.5906   26.8910     63.32
# 3         Atuona      PF  2021-11-07 06:37:43  -9.8000 -139.0333     78.30
# 4        Kavieng      PG  2021-11-07 06:39:48  -2.5744  150.7967     83.80
# 5    Provideniya      RU  2021-11-07 06:39:10  64.3833 -173.3000     17.98
# 6  Ribeira Brava      PT  2021-11-07 06:45:50  32.6500  -17.0667     66.83
# 7      Caravelas      BR  2021-11-07 06:38:53 -17.7125  -39.2481     71.01
# 8    Tuktoyaktuk      CA  2021-11-07 06:37:53  69.4541 -133.0374      6.66
# 9         Kijang      KR  2021-11-07 06:45:50  35.2442  129.2139     71.33
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        83         100       18.03          light rain
# 1        67         100       10.20     overcast clouds
# 2        91         100       12.75          light rain
# 3        70           0       16.49           clear sky
# 4        76          10       13.96          light rain
# 5        90          85        8.61     overcast clouds
# 6        55           0       11.86           clear sky
# 7        86         100        3.51     overcast clouds
# 8        95           9        7.38           clear sky
# 9        56           1       17.31           clear sky

# %%
# Export the DataFrame as a CSV file and save it
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
